# %%
## 作成したプログラム ##
## データの読み込み  ##
import KOKUSHI0624_4
from ipywidgets import interactive
# %matplotlib inline
with open("symbol.txt","r") as d:
    Symbols = d.read().split("\n")

## 個人データの選択 ## 
www = interactive(
    KOKUSHI0624_4.readdat,学科=['理学療法学科','柔道整復学科','鍼灸学科'],
    期生=[str(i)+'期生' for i in range(5,10)],
    番号=[str(i).zfill(3) for i in range(1,100)],symbol=Symbols,何問しますか=(1,100)
    )

# %%
## 設問・学生IDの選択画面へ  ##
www  # ←←
# Out:
# interactive(children=(Dropdown(description='学科', options=('理学療法学科', '柔道整復学科', '鍼灸学科'), value='理学療法学科'), Dropdown(description='期生', options=('5期生', '6期生', '7期生', '8期生', '9期生'), value='5期生'), Dropdown(description='番号', options=('001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064', '065', '066', '067', '068', '069', '070', '071', '072', '073', '074', '075', '076', '077', '078', '079', '080', '081', '082', '083', '084', '085', '086', '087', '088', '089', '090', '091', '092', '093', '094', '095', '096', '097', '098', '099'), value='001'), Dropdown(description='symbol', options=('理学療法評価', '運動療法', '理学療法概
# ...

# %%
## 問題の表示と解答の表示  ##
KOKUSHI0624_4.Letgo(www.result[0],www.result[1],www.result[2],'KOKUSHI_TEST0625/KOKU_FIG')
# Out:
# readygo
# figss
# <font size=4>[Q 0]
# 関節可動域測定法(日本整形外科学会、日本リハビリテーション医学会基準による)で誤っているのはどれか。
# None
# &emsp;&emsp;<font size=4>1. 股外旋
# &emsp;&emsp;<font size=4>2. 足屈曲（底屈）
# &emsp;&emsp;<font size=4>3. 股伸展
# &emsp;&emsp;<font size=4>4. 膝屈曲
# &emsp;&emsp;<font size=4>5. 股屈曲
# ##
# <font size=5>Enter your answer: </font><br>
# 34
# <font size=5 color='#ff1100'>mistaking:3</font><br>
# ############
#
# key word None
#
# ############
#
#
#
#
# figss
# <font size=4>[Q 0]
# Daniels らの徒手筋力テスト（足関節底屈の検査）を図に示す。正しいのはどれか。
# None
# &emsp;&emsp;<font size=4>1. 図2で完全な底屈運動が20回行えれば段階5である。
# &emsp;&emsp;<font size=4>2. 図1で完全な底屈運動ができて最大抵抗に負けずに保てれば段階2である。
# &emsp;&emsp;<font size=4>3. 図1で完全な底屈運動ができるが抵抗に耐えられなければ段階2-である。
# &emsp;&emsp;<font size=4>4. 図2で疲れなしに完全な底屈運動がl回行えれば段階3である。
# &emsp;&emsp;<font size=4>5. 図3は腓腹筋単独のテスト肢位である。
# ##
# <font size=5>Enter your answer: </font><br>
# 3
# <font size=5 color='#ff1100'>mistaking:4</font><br>
# ############
#
# key word None
#
# ############
#
#
#
#
# figss
# ...
